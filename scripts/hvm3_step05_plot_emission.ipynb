# %%
# David R Thompson
import numpy as np
import pylab as plt


coef = np.loadtxt('HVM3_Spectrometer_Emission_22.txt')
coef[0]=0
plt.plot(coef,'r')

coef = np.loadtxt('HVM3_Spectrometer_Emission_4p4.txt')
coef[0]=0
plt.plot(coef,'k')

plt.grid(True)
plt.box(False)
plt.xlabel('Channel')
plt.ylabel('Spectrometer self-emission efficiency')
# Out:
# Text(0, 0.5, 'Spectrometer self-emission efficiency')
